# %%
print("2주차")
print(10 + 20)
# Out:
# 2주차
# 30

# %%
print("1 + 2")
# Out:
# 1 + 2

# %%
import pandas as pd

# %%
a="2주차 코딩"
print(a)
# Out:
# 2주차 코딩

# %%
a=1
b=2

print(a+b)
# Out:
# 3

# %%
A=10
B=5

print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A%B)
# Out:
# 15
# 5
# 50
# 2.0
# 0

# %%
가로=12
세로=7
Perimeter=(가로*2)+(세로*2)
Area=가로*세로

print(Perimeter,'m')
print(Area,'m2')
# Out:
# 38 m
# 84 m2

# %%
국어=88
영어=92
수학=75
과목_평균=(국어+영어+수학)/3

print(과목_평균)
# Out:
# 85.0 점
